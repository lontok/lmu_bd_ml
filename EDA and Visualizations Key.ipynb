# %%
import pandas as pd
import seaborn as sns

# %%
# https://www.kaggle.com/c/boston-housing
# goal is to predict medv
# data for Boston suburbs

# %%
df = pd.read_csv('http://bit.ly/boston_housing_csv')

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
df.shape
# Out:
# (506, 14)

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df['age'].hist()

# %%
df[['rm','age','lstat']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fea341566a0>,
# ...
#       dtype=object)

# %%
sns.distplot(df['age'])

# %%
df.boxplot('medv')

# %%
'''
Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).

median (Q2/50th Percentile): the middle value of the dataset.

first quartile (Q1/25th Percentile): the middle number between the smallest number (not the “minimum”) and the median of the dataset.

third quartile (Q3/75th Percentile): the middle value between the median and the highest value (not the “maximum”) of the dataset.

interquartile range (IQR): 25th to the 75th percentile.

whiskers (shown in blue)

outliers
    decide if need to remove outliers, i.e. for regression analysis

“maximum”: Q3 + 1.5*IQR

“minimum”: Q1 -1.5*IQR

'''
# Out:
# '\nBoxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).\n\nmedian (Q2/50th Percentile): the middle value of the dataset.\n\nfirst quartile (Q1/25th Percentile): the middle number between the smallest number (not the “minimum”) and the median of the dataset.\n\nthird quartile (Q3/75th Percentile): the middle value between the median and the highest value (not the “maximum”) of the dataset.\n\ninterquartile range (IQR): 25th to the 75th percentile.\n\nwhiskers (shown in blue)\n\noutliers\n    decide if need to remove outliers, i.e. for regression analysis\n\n“maximum”: Q3 + 1.5*IQR\n\n“minimum”: Q1 -1.5*IQR\n\n'

# %%
# df.plot.<TAB>

# %%
df.plot.scatter('age','medv')

# %%
sns.pairplot(df)

# %%
df_features = df[['crim','rm','age','lstat','ptratio','medv']]

# %%
df_features.head()
# Out:
#       crim     rm   age  lstat  ptratio  medv
# 0  0.00632  6.575  65.2   4.98     15.3  24.0
# 1  0.02731  6.421  78.9   9.14     17.8  21.6
# 2  0.02729  7.185  61.1   4.03     17.8  34.7
# 3  0.03237  6.998  45.8   2.94     18.7  33.4
# 4  0.06905  7.147  54.2   5.33     18.7  36.2

# %%
sns.pairplot(df_features)

# %%
# medv target
# correlation
# negative : lstat
# positive: rm

# %%
sns.pairplot(df_features, diag_kind='kde')

# %%
#  Discretize variable into equal-sized buckets based on sample quantiles
df_features['medv_level'] = pd.qcut(df_features['medv'], 3, labels=False)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_features.sample(20)
# Out:
#          crim     rm    age  lstat  ptratio  medv  medv_level
# 406  20.71620  4.138  100.0  23.34     20.2  11.9           0
# 485   3.67367  6.312   51.9  10.58     20.2  21.2           1
# 270   0.29916  5.856   42.1  13.00     18.6  21.1           1
# 163   1.51902  8.375   93.9   3.32     14.7  50.0           2
# 450   6.71772  6.749   92.6  17.44     20.2  13.4           0
# 331   0.05023  5.706   28.4  12.43     16.9  17.1           0
# 350   0.06211  6.490   44.4   5.98     19.7  22.9           1
# 164   2.24236  5.854   91.8  11.64     14.7  22.7           1
# 494   0.27957  5.926   42.6  13.59     19.2  24.5           2
# 292   0.03615  6.630   23.4   4.70     19.2  27.9           2
# 203   0.03510  7.853   33.2   3.81     14.7  48.5           2
# 436  14.42080  6.461   93.3  18.05     20.2   9.6           0
# 470   4.34879  6.167   84.0  16.29     20.2  19.9           1
# 461   3.69311  6.376   88.4  14.65     20.2  17.7           0
# ...

# %%
# hue is good for categorical variables
sns.pairplot(df_features, hue='medv_level')
# Out:
# /opt/conda/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /opt/conda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
df_features.corr()
# Out:
#                 crim        rm       age     lstat   ptratio      medv  \
# crim        1.000000 -0.219247  0.352734  0.455621  0.289946 -0.388305
# rm         -0.219247  1.000000 -0.240265 -0.613808 -0.355501  0.695360
# age         0.352734 -0.240265  1.000000  0.602339  0.261515 -0.376955
# lstat       0.455621 -0.613808  0.602339  1.000000  0.374044 -0.737663
# ptratio     0.289946 -0.355501  0.261515  0.374044  1.000000 -0.507787
# medv       -0.388305  0.695360 -0.376955 -0.737663 -0.507787  1.000000
# medv_level -0.381672  0.559745 -0.523519 -0.751431 -0.474299  0.818108
#
#             medv_level
# crim         -0.381672
# rm            0.559745
# age          -0.523519
# lstat        -0.751431
# ptratio      -0.474299
# medv          0.818108
# medv_level    1.000000

# %%
'''
Represent the linear dependence of two variables or sets of data.
The correlation coefficient ranges from -1 to 1. 
If the value is close to 1, it means that there is a strong positive correlation 
between the two variables. 
When it is close to -1, the variables have a strong negative correlation.
'''
# Out:
# '\nRepresent the linear dependence of two variables or sets of data.\nThe correlation coefficient ranges from -1 to 1. \nIf the value is close to 1, it means that there is a strong positive correlation \nbetween the two variables. \nWhen it is close to -1, the variables have a strong negative correlation.\n'

# %%
# easier to interpret visually
sns.heatmap(df_features.corr(), 
         xticklabels=df_features.corr().columns, 
         yticklabels=df_features.corr().columns,
            annot=True)

# %%
'''
light = positive correlation
dark = negative correlation
'''
# Out:
# '\nlight = positive correlation\ndark = negative correlation\n'
